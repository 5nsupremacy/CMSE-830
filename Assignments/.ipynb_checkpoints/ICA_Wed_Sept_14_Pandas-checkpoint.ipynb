# %% [markdown]
# Put your name here:
# * Saumya Shah
#
#
# Put the names of the people you worked with here:
# * Tanishq Tanmay (iris)
# * Parth Maheshwari (
# * Kuldeep Singh (mpg)
# * KSD Teja ()
#
# Our group divided the datasets according to:
#
# > `I am taking Penguins dataset`

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# sns.get_dataset_names()

# %%
df_peng = sns.load_dataset("penguins")
df_iris = sns.load_dataset("iris")
df_mpg = sns.load_dataset("mpg")
df_tita = sns.load_dataset("titanic")

# %% [markdown]
# ____
# # Wed ICA
# ____
#
# This ICA will spill over into the Friday ICA. You are not expected to finish this today, but you can get started so that you have more time on Friday.
#
# So that you don't get too used to a given dataset, we have opened three above. You have some options:
# * each person in your group chooses their own dataset,
# * you use as many datasets as there are people in your group, but you all work on them together,
# * or, if your group is very large, use at least four datasets.

# %% [markdown]
# ____
# ## Tip
# ____
#
# Pandas is a very large library. Even if I walked you through each and everything it did, you would have forgotten most of it by the time we reached the end next year.
#
# It is therefore better for you to master the most basic, commonly-used operations and know where to look up more complex data science manipulations.
#
# Of course, perhaps the best place to start is the `Pandas` [documentation itself](https://pandas.pydata.org/).
#
# Over time, you will find little gems that really organize how to get stuff done with Pandas. One of my favorites is [this website](https://chrisalbon.com/). It is a vast "how-to" guide for data science.
#
# Bookmark these webpages!

# %% [markdown]
# ___
# # IDA
# ___
#
# ## [`.head()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) & [`.tail()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)
# We are going to start with some simple inspections of the datasets. Inspect all of your chosen datasets using `.head()`. Be sure to vary the number of rows you look at.
#
# ✍️ In a markdown cell, discuss any issues you see with the data.

# %%
df_peng
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# - We can see NaN values in the DataFrame

# %% [markdown]
# Before we get too far, let's explore various ways we can display a dataframe. Of course, we can simply type the name, as in `df_iris`, and press shift-enter. The notebook shows us the top and bottom of the notebook, with the middle not shown. We saw above how to see the top, using `.head()`. Of course, we can also see just the bottom using `.tail()`.
#
# ✍️ Try using `.tail()` so that you can see what it does in comparison to the two other approaches.

# %%
df_peng.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df_peng.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %% [markdown]
# ## [`.style`](https://pandas.pydata.org/docs/user_guide/style.html)
#
# This part you are going to have fun with! Go to [this webpage](https://pandas.pydata.org/docs/user_guide/style.html) and read what is there.
#
# ✍️ With your group, spend some time trying various options for the different datasets. If you are working on the same dataset over a long period of time, this will help keep your mind focused on the organizational structure of your data. Show several examples of how `style` can be used.
#
# Also, notice that you can generate long "dot chains" in `Pandas`. Here is a simple example to get you started. Here I highlight the non-numeric data.

# %%
df_peng.head(10).style.set_properties(**{'background-color': 'green'}, subset=['species']).set_properties(**{'background-color': 'blue'}, subset=['sex']).set_properties(**{'background-color': 'yellow'}, subset=['island'])
# Out:
# <style type="text/css">
# #T_b19e2_row0_col0, #T_b19e2_row1_col0, #T_b19e2_row2_col0, #T_b19e2_row3_col0, #T_b19e2_row4_col0, #T_b19e2_row5_col0, #T_b19e2_row6_col0, #T_b19e2_row7_col0, #T_b19e2_row8_col0, #T_b19e2_row9_col0 {
#   background-color: green;
# }
# #T_b19e2_row0_col1, #T_b19e2_row1_col1, #T_b19e2_row2_col1, #T_b19e2_row3_col1, #T_b19e2_row4_col1, #T_b19e2_row5_col1, #T_b19e2_row6_col1, #T_b19e2_row7_col1, #T_b19e2_row8_col1, #T_b19e2_row9_col1 {
#   background-color: yellow;
# }
# #T_b19e2_row0_col6, #T_b19e2_row1_col6, #T_b19e2_row2_col6, #T_b19e2_row3_col6, #T_b19e2_row4_col6, #T_b19e2_row5_col6, #T_b19e2_row6_col6, #T_b19e2_row7_col6, #T_b19e2_row8_col6, #T_b19e2_row9_col6 {
#   background-color: blue;
# }
# </style>
# <table id="T_b19e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b19e2_level0_col0" class="col_heading level0 col0" >species</th>
#       <th id="T_b19e2_level0_col1" class="col_heading level0 col1" >island</th>
#       <th id="T_b19e2_level0_col2" class="col_heading level0 col2" >bill_length_mm</th>
#       <th id="T_b19e2_level0_col3" class="col_heading level0 col3" >bill_depth_mm</th>
#       <th id="T_b19e2_level0_col4" class="col_heading level0 col4" >flipper_length_mm</th>
#       <th id="T_b19e2_level0_col5" class="col_heading level0 col5" >body_mass_g</th>
#       <th id="T_b19e2_level0_col6" class="col_heading level0 col6" >sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b19e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b19e2_row0_col0" class="data row0 col0" >Adelie</td>
#       <td id="T_b19e2_row0_col1" class="data row0 col1" >Torgersen</td>
#       <td id="T_b19e2_row0_col2" class="data row0 col2" >39.100000</td>
#       <td id="T_b19e2_row0_col3" class="data row0 col3" >18.700000</td>
#       <td id="T_b19e2_row0_col4" class="data row0 col4" >181.000000</td>
#       <td id="T_b19e2_row0_col5" class="data row0 col5" >3750.000000</td>
#       <td id="T_b19e2_row0_col6" class="data row0 col6" >Male</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b19e2_row1_col0" class="data row1 col0" >Adelie</td>
#       <td id="T_b19e2_row1_col1" class="data row1 col1" >Torgersen</td>
#       <td id="T_b19e2_row1_col2" class="data row1 col2" >39.500000</td>
#       <td id="T_b19e2_row1_col3" class="data row1 col3" >17.400000</td>
#       <td id="T_b19e2_row1_col4" class="data row1 col4" >186.000000</td>
#       <td id="T_b19e2_row1_col5" class="data row1 col5" >3800.000000</td>
#       <td id="T_b19e2_row1_col6" class="data row1 col6" >Female</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b19e2_row2_col0" class="data row2 col0" >Adelie</td>
#       <td id="T_b19e2_row2_col1" class="data row2 col1" >Torgersen</td>
#       <td id="T_b19e2_row2_col2" class="data row2 col2" >40.300000</td>
#       <td id="T_b19e2_row2_col3" class="data row2 col3" >18.000000</td>
#       <td id="T_b19e2_row2_col4" class="data row2 col4" >195.000000</td>
#       <td id="T_b19e2_row2_col5" class="data row2 col5" >3250.000000</td>
#       <td id="T_b19e2_row2_col6" class="data row2 col6" >Female</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b19e2_row3_col0" class="data row3 col0" >Adelie</td>
#       <td id="T_b19e2_row3_col1" class="data row3 col1" >Torgersen</td>
#       <td id="T_b19e2_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_b19e2_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_b19e2_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_b19e2_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_b19e2_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b19e2_row4_col0" class="data row4 col0" >Adelie</td>
#       <td id="T_b19e2_row4_col1" class="data row4 col1" >Torgersen</td>
#       <td id="T_b19e2_row4_col2" class="data row4 col2" >36.700000</td>
#       <td id="T_b19e2_row4_col3" class="data row4 col3" >19.300000</td>
#       <td id="T_b19e2_row4_col4" class="data row4 col4" >193.000000</td>
#       <td id="T_b19e2_row4_col5" class="data row4 col5" >3450.000000</td>
#       <td id="T_b19e2_row4_col6" class="data row4 col6" >Female</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b19e2_row5_col0" class="data row5 col0" >Adelie</td>
#       <td id="T_b19e2_row5_col1" class="data row5 col1" >Torgersen</td>
#       <td id="T_b19e2_row5_col2" class="data row5 col2" >39.300000</td>
#       <td id="T_b19e2_row5_col3" class="data row5 col3" >20.600000</td>
#       <td id="T_b19e2_row5_col4" class="data row5 col4" >190.000000</td>
#       <td id="T_b19e2_row5_col5" class="data row5 col5" >3650.000000</td>
#       <td id="T_b19e2_row5_col6" class="data row5 col6" >Male</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b19e2_row6_col0" class="data row6 col0" >Adelie</td>
#       <td id="T_b19e2_row6_col1" class="data row6 col1" >Torgersen</td>
#       <td id="T_b19e2_row6_col2" class="data row6 col2" >38.900000</td>
#       <td id="T_b19e2_row6_col3" class="data row6 col3" >17.800000</td>
#       <td id="T_b19e2_row6_col4" class="data row6 col4" >181.000000</td>
#       <td id="T_b19e2_row6_col5" class="data row6 col5" >3625.000000</td>
#       <td id="T_b19e2_row6_col6" class="data row6 col6" >Female</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b19e2_row7_col0" class="data row7 col0" >Adelie</td>
#       <td id="T_b19e2_row7_col1" class="data row7 col1" >Torgersen</td>
#       <td id="T_b19e2_row7_col2" class="data row7 col2" >39.200000</td>
#       <td id="T_b19e2_row7_col3" class="data row7 col3" >19.600000</td>
#       <td id="T_b19e2_row7_col4" class="data row7 col4" >195.000000</td>
#       <td id="T_b19e2_row7_col5" class="data row7 col5" >4675.000000</td>
#       <td id="T_b19e2_row7_col6" class="data row7 col6" >Male</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b19e2_row8_col0" class="data row8 col0" >Adelie</td>
#       <td id="T_b19e2_row8_col1" class="data row8 col1" >Torgersen</td>
#       <td id="T_b19e2_row8_col2" class="data row8 col2" >34.100000</td>
#       <td id="T_b19e2_row8_col3" class="data row8 col3" >18.100000</td>
#       <td id="T_b19e2_row8_col4" class="data row8 col4" >193.000000</td>
#       <td id="T_b19e2_row8_col5" class="data row8 col5" >3475.000000</td>
#       <td id="T_b19e2_row8_col6" class="data row8 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b19e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b19e2_row9_col0" class="data row9 col0" >Adelie</td>
#       <td id="T_b19e2_row9_col1" class="data row9 col1" >Torgersen</td>
#       <td id="T_b19e2_row9_col2" class="data row9 col2" >42.000000</td>
#       <td id="T_b19e2_row9_col3" class="data row9 col3" >20.200000</td>
#       <td id="T_b19e2_row9_col4" class="data row9 col4" >190.000000</td>
#       <td id="T_b19e2_row9_col5" class="data row9 col5" >4250.000000</td>
#       <td id="T_b19e2_row9_col6" class="data row9 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## [`.isna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)
#
# You will soon see that data science relies heavily on Boolean variables. The reason for this is simple: a very common operation is testing some aspect of your data. _Is this true? Is that true? Is this greater than that? Is this between this and that_ You get the idea: there are **many** questions we want to ask that have an answer "yes" or "no".
#
# Or, in a computer: "true" or "false".
#
# ✍🏻 Take all of your datasets and add `isna()` to the end of the name (e.g., `df_tita.isna()`). What do you get? Discuss what you see. In particular, among the datasets you looked at above that had potential problems, what does the output tell you?

# %%
df_peng.isna()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %% [markdown]
# - pandas.DataFrame.isna() and pandas.DataFrame.isnull() represent the same function

# %% [markdown]
# ## [`.isnull()`](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)
#
# ✍🏻 Using the internet, figure out what the difference is between `isna()` and `isnull()`. Put your answer in a markdown cell.

# %%
df_peng.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# ## [`.corr()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) & [`.describe()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
#
# Looking ahead to geting quick statistics from our dataset, we have already looked at `.describe`. ✍🏻 Practice with `.describe()` to be sure everyone in your groups knows what it can tell you.
#
# ✍🏻 Next, try `.corr` with all of our chosen datasets. Discuss what your group sees in a markdown cell. In particular: what does `.corr()` return? What are the rows? What are the colulmns? Is there a connection to Seaborn's `pairplot`? Try several of the options (e.g., Spearman, Kendall, etc.)

# %% [markdown]
# > **Each plot in seaborn reprsents correlation of one feature to another. Hence if we try to best fit the plots, we would get these (below) values as coefficients**

# %%
df_peng.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
df_peng.corr(method = 'spearman')
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.221749           0.672772
# bill_depth_mm           -0.221749       1.000000          -0.523267
# flipper_length_mm        0.672772      -0.523267           1.000000
# body_mass_g              0.583800      -0.432372           0.839974
#
#                    body_mass_g
# bill_length_mm        0.583800
# bill_depth_mm        -0.432372
# flipper_length_mm     0.839974
# body_mass_g           1.000000

# %%
df_peng.corr(method = 'kendall')
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.122850           0.483345
# bill_depth_mm           -0.122850       1.000000          -0.281894
# flipper_length_mm        0.483345      -0.281894           1.000000
# body_mass_g              0.433359      -0.195070           0.660467
#
#                    body_mass_g
# bill_length_mm        0.433359
# bill_depth_mm        -0.195070
# flipper_length_mm     0.660467
# body_mass_g           1.000000

# %%
df_peng.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
